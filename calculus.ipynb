# %%
import array_calculus as array
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Classwrok 09
# ## Monica Hiemer,Jessica Trawick, Gage Kizzar
#
# In this assignment we created a gradient called a central diffrence matrix, that would help us compute derivatives of functions. This was able to bb done, by Recalling that the derivative of a function $f$ at a point $x$ is defined as the limit: $$f'(x) = \frac{df}{dx}(x) = Df(x) \equiv \lim_{h \to 0} \frac{f(x+h) - f(x)}{(x + h) - x} = \lim_{h\to 0} \frac{f(x) - f(x - h)}{x - (x - h)} = \lim_{h \to 0} \frac{f(x+h) - f(x-h)}{(x+h)-(x-h)}$$
#
# Taking this information and working backwords from having the f'(x) we were able to find out the gradient. Which is shown bellow.

# %%
array.gradient(1, 5 , 5)
# Out:
# array([[-1. ,  1. ,  0. ,  0. ,  0. ],
#        [-0.5,  0. ,  0.5,  0. ,  0. ],
#        [ 0. , -0.5,  0. ,  0.5,  0. ],
#        [ 0. ,  0. , -0.5,  0. ,  0.5],
#        [ 0. ,  0. ,  0. , -1. ,  1. ]])

# %% [markdown]
# #### Fucntion $f(x)= x^2$
# The function shown in the graph is $x^2$ and is displayed as blue and its deriviatve is dispalayed as orange. Both are evaluated at 10 points.

# %%
array.f_plot(1, 10, 10)

# %% [markdown]
# #### Function $f(x) = x^2$
# This is the same function as above but this graph is computing the derivative using the gradent fucntion we created. Both graphs are the same, showing that the function works and computes the same values as above

# %%
array.f_plot_grad(1,10,10)

# %% [markdown]
# #### Function $f(x) = x^2$
# This is the same function as above but showing that squaring your derivative matrix, makes the function and the derivative more acurrate.

# %%
array.f_plot(1, 10, 100 )

# %% [markdown]
# #### Fucntion $f(x)= sin(x)$
# The function shown in the graph is $sin(x)$ and is displayed as blue and its deriviatve is dispalayed as orange. Both are evaluated at 10 points.

# %%
array.s_plot(1, 10, 10)

# %% [markdown]
# #### Function $f(x) = sin(x)$
# This is the same function as above but this graph is computing the derivative using the gradient fucntion we created. Both graphs are the same, showing that the function works and computes the same values as above

# %%
array.s_polt_grad(1, 10 , 10 )

# %% [markdown]
# #### Function $f(x) = sin(x)$
# This is the same function as above but showing that squaring your derivative matrix, makes the function and the derivative more acurrate.

# %%
array.s_plot(1, 10 , 100)

# %% [markdown]
# #### Function $f(x)= e^{-x^2/2}/\sqrt{2\pi}$
# The function shown in the graph is $e^{-x^2/2}/\sqrt{2\pi}$ and is displayed as blue and its deriviatve is dispalayed as orange. Both are evaluated at 10 points.

# %%
array.g_plot(1, 10 , 10)

# %% [markdown]
# #### Function $f(x)= e^{-x^2/2}/\sqrt{2\pi}$
#
# This is the same function as above but this graph is computing the derivative using the gradient fucntion we created. Both graphs are the same, showing that the function works and computes the same values as above

# %%
array.g_plot_grad(1, 10 ,10)

# %% [markdown]
# #### Function $f(x)= e^{-x^2/2}/\sqrt{2\pi}$
# This is the same function as above but showing that squaring your derivative matrix, makes the function and the derivative more acurrate.

# %%
array.g_plot(1, 10 , 100)
